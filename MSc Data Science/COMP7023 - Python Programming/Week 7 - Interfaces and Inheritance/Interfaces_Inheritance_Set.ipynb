# %% [markdown]
# ## Question 1
# Define a class `Vehicle` with `brand` and method `info()`.
# Define subclass `Car` adding `doors` and overriding `info()`.
# Instantiate `Car("BMW", 3)` and call `info()`.

# %%
# your code here

# %%
# asserts
car = Car("BMW", 3)
assert car.brand == "BMW"
assert car.doors == 3
assert "BMW" in car.info()
assert "3" in car.info()

# %% [markdown]
# ## Question 2
# Override `deposit` in `RewardsAccount` using `super()` to add a reward after depositing.

# %%
# your code here

# %%
# asserts
a = RewardsAccount("A")
a.deposit(10)
assert a.balance == 11

# %% [markdown]
# ## Question 3
# Predict output and explain lookup rules for the given A→B→C inheritance printing x.

# %%
# your code here

# %%
# asserts
# Must define A,B,C exactly as remit
assert A.x == 10
assert B.x == 10
assert C.x == 20
assert C().x == 20

# %% [markdown]
# ## Question 4
# Fix the incorrect `super.greet()` call and explain the error.

# %%
# your code here

# %%
# asserts
p = Parent()
c = Child()
assert p.greet() == "hello"
assert c.greet() == "HELLO"

# %% [markdown]
# ## Question 5
# Identify shared interface of exporters, write `save_all(exporters, df)`, and explain why no inheritance is required.

# %%
# your code here

# %%
# asserts
class DummyDF:
    def to_csv(self): return "CSV"
    def to_json(self): return "JSON"

df = DummyDF()
out = save_all([CSVExporter(), JSONExporter()], df)
assert out == ["CSV", "JSON"]

# %% [markdown]
# ## Question 6
# Given X→Y→Z overriding value, determine attribute resolutions before/after instance shadowing.

# %%
# your code here

# %%
# asserts
assert Z.value == 10  # inherited from Y
z = Z()
assert z.value == 10
z.value = 99
assert z.value == 99
assert Z.value == 10
assert Y.value == 10

# %% [markdown]
# ## Question 7
# Predict D().f() and list full MRO for classes A,B,C,D under multiple inheritance.

# %%
# your code here

# %%
# asserts
d = D()
assert d.f() == "B"
m = [cls.__name__ for cls in D.mro()]
assert m[:4] == ["D", "B", "C", "A"]

# %% [markdown]
# ## Question 8
# Write `total_assets(accounts)` that sums `.balance` for any object with that attribute.

# %%
# your code here

# %%
# asserts
class T: 
    def __init__(self,b): self.balance=b

assert total_assets([T(3),T(7)]) == 10

# %% [markdown]
# ## Question 9
# Implement Vector2D supporting `__add__` and `__repr__`.

# %%
# your code here

# %%
# asserts
v1 = Vector2D(1,2)
v2 = Vector2D(3,4)
v3 = v1+v2
assert (v3.x, v3.y) == (4,6)
assert "Vector2D" in repr(v3)

# %% [markdown]
# ## Question 10
# Implement function `add_number(x, y)` with mixed-type dispatch for Rational and int.

# %%
# your code here

# %%
# asserts
r1 = Rational(1,2)
r2 = Rational(1,3)
r = add_number(r1,r2)
assert isinstance(r,Rational)
assert (r.numer, r.denom) == (5,6)
assert add_number(3,4) == 7

# %% [markdown]
# ## Question 11
# Fill in a minimal hand-built object system: make_class, make_instance, get lookup.

# %%
# your code here

# %%
# asserts
A = make_class({"x": 5})
a = make_instance(A)
assert a["get"]("x") == 5

# %% [markdown]
# ## Question 12
# Explain why Python allows unrelated classes to work together if they implement same method names.

# %%
# your code here

# %%
# asserts
# No strict tests; just ensure cell runs
pass
