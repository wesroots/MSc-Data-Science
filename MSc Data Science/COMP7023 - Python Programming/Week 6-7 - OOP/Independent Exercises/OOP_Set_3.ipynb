# %% [markdown]
# # OOP Independent Exercises – Set 3A moderate step up from Set 2 without introducing advanced external topics.

# %% [markdown]
# Q1 — BoundedListCreate a class `BoundedList` that stores items but never allows the list to exceed a fixed size.Methods:- `add(x)` → adds to end unless full.- `pop()` → removes and returns last element.- `is_full()` / `is_empty()`.Internal list must never exceed the capacity.

# %%
# Your code here

# %%
# Testsbl = BoundedList(3)assert bl.is_empty()bl.add(1); bl.add(2); bl.add(3)assert bl.is_full()bl.add(99)  # ignoredassert bl.pop()==3assert not bl.is_full()print("Q1 OK")

# %% [markdown]
# Q2 — ScoreTrackerCreate a class `ScoreTracker` that maps names → scores.Requirements:- `add(name, score)` adds or updates.- `highest()` returns (name,score) of highest score.- `average()` returns mean score.- Internal dict must not leak.

# %%
# Your code here

# %%
# Testsst=ScoreTracker()st.add("A",10); st.add("B",5); st.add("A",15)assert st.highest()==("A",15)assert abs(st.average()-10)==0print("Q2 OK")

# %% [markdown]
# Q3 — WordBagCreate a class `WordBag` storing word counts.- `add(word)` increases count.- `remove(word)` decreases count or deletes.- `count(word)` returns count.- `unique()` returns number of distinct words.

# %%
# Your code here

# %%
# Testswb=WordBag()wb.add("hi"); wb.add("hi"); wb.add("bye")assert wb.count("hi")==2wb.remove("hi")assert wb.count("hi")==1assert wb.unique()==2print("Q3 OK")

# %% [markdown]
# Q4 — StudentRegistryCreate a class storing student records as dicts: {name, age}.- `add_student(name, age)`- `find(name)` → returns copy of record or None.- `all_ages()` → list of ages.- Must store internal copies.

# %%
# Your code here

# %%
# Testssr=StudentRegistry()sr.add_student("A",20); sr.add_student("B",25)rec=sr.find("A")assert rec["age"]==20rec["age"]=99assert sr.find("A")["age"]==20assert sorted(sr.all_ages())==[20,25]print("Q4 OK")

# %% [markdown]
# Q5 — SimpleTableCreate a Table class:- Stores rows as dicts.- `add_row(d)` stores COPY.- `select(col)` returns list of that column’s values.- `filter(col,val)` returns list of row copies where row[col]==val.

# %%
# Your code here

# %%
# Testst=SimpleTable()t.add_row({"A":1,"B":2})t.add_row({"A":1,"B":9})assert t.select("A")==[1,1]rows=t.filter("B",2)assert rows[0]["A"]==1rows[0]["A"]=99assert t.filter("B",2)[0]["A"]==1print("Q5 OK")

# %% [markdown]
# Q6 — RectangleA simple geometry class:- init with width, height.- `area()`, `perimeter()`- `scale(f)` returns NEW Rectangle scaled.Ensure immutability: scaling must not change the original.

# %%
# Your code here

# %%
# Testsr=Rectangle(2,4)assert r.area()==8assert r.perimeter()==12r2=r.scale(2)assert r2.area()==32assert r.area()==8print("Q6 OK")

# %% [markdown]
# Q7 — HistoryListLike a list but keeps a history of all values ever appended.- `add(x)`- `current()` returns current list copy.- `history()` returns list of snapshots (each snapshot is its own list copy).

# %%
# Your code here

# %%
# Testsh=HistoryList()h.add(1); h.add(2)cur=h.current()assert cur==[1,2]hist=h.history()assert len(hist)==2hist[0].append(99)assert h.history()[0]==[1]print("Q7 OK")

# %% [markdown]
# Q8 — TagCounterTrack tags and their counts.- `add(tag)`- `most_common()` returns tag with highest count.- `merge(other)` merges counts from another TagCounter (copying values).

# %%
# Your code here

# %%
# Teststc=TagCounter()tc.add("x"); tc.add("x"); tc.add("y")assert tc.most_common()=="x"tc2=TagCounter(); tc2.add("y"); tc2.add("y")tc.merge(tc2)assert tc.count("y")==3print("Q8 OK")

# %% [markdown]
# Q9 — LimitedQueueQueue with max length.- `enqueue(x)` adds unless full.- `dequeue()` removes FIFO.- `peek()` shows next item.- Must preserve order.

# %%
# Your code here

# %%
# Testsq=LimitedQueue(2)q.enqueue(1); q.enqueue(2)q.enqueue(3)assert q.peek()==1assert q.dequeue()==1assert q.dequeue()==2assert q.dequeue() is Noneprint("Q9 OK")

# %% [markdown]
# Q10 — KeyViewCreate a wrapper around a dictionary.- Store COPY internally.- `keys_starting_with(prefix)` returns list of keys beginning with prefix.- `values_for(keys)` returns list of values for given list of keys.- Must remain safe from external mutation.

# %%
# Your code here

# %%
# Testskv=KeyView({"apple":1,"ape":2,"bat":3})ks=kv.keys_starting_with("ap")assert set(ks)=={"apple","ape"}vals=kv.values_for(["apple","bat"])assert vals==[1,3]print("Q10 OK")
