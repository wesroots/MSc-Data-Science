# %% [markdown]
# ### 1. Which value (or object) does each of the following expressions evaluate to?
# Think first of your answer, before you enter the expression into the REPL and check. Think about unexpected results.
#
# (a) 2 * 3 + 1
# (b) 2 * 3+1
# (c) 1 + 2
# (d) 1 + 2 * 3
# (e) 0.1 + 0.2 + 0.3
# (f) 0.3 + 0.2 + 0.1
# (g) 0.1 + (0.2 + 0.3)
# (h) 3 * 0.1
# (i) 1/3 * 3
# (j) min(pow(2,3), pow(3,2))
# (k) abs(round(pow(-2,5) / 5))
# (l) round(pow(10, 30) / 10)
# (m) "hello" + ' ' + "world"
# (n) "hello"[3]
# (o) "hello"[-1]
# (p) "hello"[8]
# (q) "hello"[2:]
# (r) "hello"[-1::-3]
# (s) len("hello"[2:4])

# %% [markdown]
# ### 2. For each of the values you obtained in the preceding exercise, what is its type?

# %% [markdown]
# (a) 2 * 3 + 1 -> int
# (b) 2 * 3+1 -> int
# (c) 1 + 2 -> int
# (d) 1 + 2 * 3 -> int
# (e) 0.1 + 0.2 + 0.3 -> float
# (f) 0.3 + 0.2 + 0.1 -> float
# (g) 0.1 + (0.2 + 0.3) -> float
# (h) 3 * 0.1 -> float
# (i) 1/3 * 3 -> float
# (j) min(pow(2,3), pow(3,2)) -> int
# (k) abs(round(pow(-2,5) / 5)) -> int
# (l) round(pow(10, 30) / 10) -> float
# (m) "hello" + ' ' + "world" -> str
# (n) "hello"[3] -> str
# (o) "hello"[-1] -> str
# (p) "hello"[8] -> str
# (q) "hello"[2:] -> str
# (r) "hello"[-1::-3] -> str
# (s) len("hello"[2:4]) -> int

# %%
a = len("hello"[2:4])
print(type(a))
# Out:
# <class 'int'>

# %% [markdown]
# ### 3. Expressions and String Manipulation
# **(a)** Create 5 different expressions that evaluate to 2025, using only numeric literals, the operators `+`, `-`, `*` and parentheses.
#
# **(b)** Create 5 different expressions that evaluate to `"abba"`, using only string literals, the operators `+` and `*`, slicing and parentheses.
#
# **(c)** Use slicing to obtain from the string literal `"hello"` the strings `"hell"`, `"lo"`, `""`, `"o"` and `"olleh"`.

# %%
# (a) Create 5 different expressions that evaluate to 2025, using only numeric literals, the operators `+`, `-`, `*` and parentheses.
int1 = 200*10+25
print(f"(a) = {int1}")

# (b) Create 5 different expressions that evaluate to `"abba"`, using only string literals, the operators `+` and `*`, slicing and parentheses.
str1 = "ab"
str2 = "ba"
print(f"(b) = {str1 + str2}")

# (c) Use slicing to obtain from the string literal "hello" the strings "hell", "lo", "", "o" and "olleh".
c = "hello"
string1 = c[0:4]
string2 = c[4:5]
string3 = c[2:2]
string4 = c[4]
string5 = c[::-1]
print(f"(c) = {string1}, {string2}, {string3}, {string4}, {string5}")
# Out:
# (a) = 2025
# (b) = abba
# (c) = hell, o, , o, olleh

# %% [markdown]
# ### 4. Calculating Volumes and Surface Areas
# Start writing a Python program with:
# ```python
# from math import pi
# radius = 10
# circle_circumference = 2 * pi * radius
# height = 20
# ```
# Find formulas for the volume and surface area of a cylinder and a cone.
# Then extend the program to calculate the volume and surface area of a cylinder and a cone of the given radius and height, binding also intermediate values to meaningful names.

# %%
from math import pi

def cyl_vol(radius, height):
    base_circumference = 2*pi*radius
    return base_circumference*height

print(f"Cylinder volume = {cyl_vol(2,3)}")
# Out:
# Cylinder volume = 37.69911184307752

# %% [markdown]
# ### 5. Writing Functions
# The previous Python program calculates with fixed values for radius and height.
# To easily calculate the various volumes and areas for differently sized cylinders and cones, define functions with appropriate formal parameters that calculate these values.
#
# Start with:
# ```python
# from math import pi, sqrt
#
# def circle_circumference(radius):
#     return 2 * pi * radius
# ```

# %%
from math import pi, sqrt

def circle_circumference(radius):
    return 2* pi * radius

print(circle_circumference(2))
# Out:
# 12.566370614359172

# %% [markdown]
# ### 6. String Functions
# Define the following functions that take one string as a formal parameter:
#
# **(a)** A function `head` that returns the first character of a string.
# **(b)** A function `tail` that returns the given string without its first character.
# **(c)** A function that also takes a number `n` as a second formal parameter and returns the nth character of the string, but counting characters starting at 1 (so for `"Python"` and `3` it should return `"t"`).
# **(d)** A function that reverses the given string (so `"Python"` becomes `"nohtyP"`).

# %%
# (a)
def head(string):
    return string[0]

print(head("String"))
# Out:
# S

# %%
# (b)
def tail(tail_input):
    input_len = len(tail_input)
    return tail_input[input_len-1]

print(tail("String"))
# Out:
# g

# %%
# (c)
def func(string_input, n):
    return string_input[n-1]

print(func("String", 3))
# Out:
# r

# %%
# (d) - A function that reverses the given string (so `"Python"` becomes `"nohtyP"`).

def func2(input_string_2):
    reversed_input = input_string_2[::-1]
    return reversed_input

print(func2("Python"))
# Out:
# nohtyP
