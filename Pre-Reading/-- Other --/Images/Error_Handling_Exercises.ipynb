# %% [markdown]
# # Exceptions (try & except) Exercises

# %% [markdown]
# **Exercise:** 1. Write code that divides two numbers entered by the user. Use `try/except` to catch division by zero and print a friendly message.

# %%
# Write your solution here

# %% [markdown]
# **Exercise:** 2. Write code that asks the user to enter an integer. If they enter something invalid (like 'abc'), catch the `ValueError` and ask again.

# %%
# Write your solution here

# %% [markdown]
# **Exercise:** 3. Simulate a risky operation by trying to open a non-existent file. Handle the `FileNotFoundError`.

# %%
# Write your solution here

# %% [markdown]
# **Exercise:** 4. Create a program that uses `try/except` to attempt converting a list of strings into integers. Handle any errors and skip invalid entries.

# %%
# Write your solution here

# %% [markdown]
# **Exercise:** 5. Debugging exercise: given code `print(10/0)` → modify it to avoid crashing using error handling.

# %%
# Write your solution here

# %% [markdown]
# # The else and finally blocks Exercises

# %% [markdown]
# **Exercise:** 1. Write a program that opens a file safely. Use `else` to print 'File opened successfully' only if no error occurs.

# %%
# Write your solution here

# %% [markdown]
# **Exercise:** 2. Modify the program to include a `finally` block that always prints 'Execution finished' whether or not an error occurs.

# %%
# Write your solution here

# %% [markdown]
# **Exercise:** 3. Demonstrate the difference between putting a success message in `else` vs in `try`.

# %%
# Write your solution here

# %% [markdown]
# **Exercise:** 4. Deliberately raise an error in the `try` block and show that `finally` still runs.

# %%
# Write your solution here

# %% [markdown]
# **Exercise:** 5. Write a program that tries to divide numbers, uses `else` to confirm division success, and `finally` to always print 'Done'.

# %%
# Write your solution here

# %% [markdown]
# # Raising Exceptions Exercises

# %% [markdown]
# **Exercise:** 1. Write a function `check_positive(x)` that raises a `ValueError` if `x` is negative.

# %%
# Write your solution here

# %% [markdown]
# **Exercise:** 2. Write a function that takes a filename and raises `FileNotFoundError` if the file does not exist (hint: use `os.path.exists`).

# %%
# Write your solution here

# %% [markdown]
# **Exercise:** 3. Define a custom exception `NegativeNumberError` and raise it if the input is < 0.

# %%
# Write your solution here

# %% [markdown]
# **Exercise:** 4. Modify a function so it raises a `TypeError` if input is not a string.

# %%
# Write your solution here

# %% [markdown]
# **Exercise:** 5. Create a function that raises an exception if the input list is empty. Handle the exception when calling it.

# %%
# Write your solution here

# %% [markdown]
# # Catching Multiple Exceptions Exercises

# %% [markdown]
# **Exercise:** 1. Write code that tries to convert input to an integer and divide 100 by it. Catch both `ValueError` and `ZeroDivisionError`.

# %%
# Write your solution here

# %% [markdown]
# **Exercise:** 2. Use a single `except (TypeError, ValueError) as e` block to catch errors from invalid operations.

# %%
# Write your solution here

# %% [markdown]
# **Exercise:** 3. Demonstrate what happens when you catch all errors with `except Exception as e`.

# %%
# Write your solution here

# %% [markdown]
# **Exercise:** 4. Create code that deliberately triggers both `KeyError` and `IndexError`. Catch them with one block.

# %%
# Write your solution here

# %% [markdown]
# **Exercise:** 5. Debugging exercise: given code `print(1+'a')` modify it to handle the error gracefully.

# %%
# Write your solution here

# %% [markdown]
# # Common Errors in Data Science Exercises

# %% [markdown]
# **Exercise:** 1. Create a dictionary and deliberately access a missing key. Handle the `KeyError`.

# %%
# Write your solution here

# %% [markdown]
# **Exercise:** 2. Create a list with 3 elements and deliberately access index 5. Catch the `IndexError`.

# %%
# Write your solution here

# %% [markdown]
# **Exercise:** 3. Try to convert the string 'abc' into an integer. Catch the `ValueError`.

# %%
# Write your solution here

# %% [markdown]
# **Exercise:** 4. Write code that tries to add a string and an integer. Catch the `TypeError`.

# %%
# Write your solution here

# %% [markdown]
# **Exercise:** 5. Try to open a non-existent CSV file and handle the `FileNotFoundError`.

# %%
# Write your solution here
