# %% [markdown]
# # Importing Modules Exercises

# %% [markdown]
# **Exercise:** 1. Import the `math` module and use it to calculate the square root, logarithm (base e), and cosine of any number you choose.

# %%
# Write your solution here

# %% [markdown]
# **Exercise:** 2. Use `from math import pi, sqrt` and calculate the area of a circle with radius 7 using only the imported functions.

# %%
# Write your solution here

# %% [markdown]
# **Exercise:** 3. Import the `random` module as `rnd` and generate 5 random integers between 1 and 100.

# %%
# Write your solution here

# %% [markdown]
# **Exercise:** 4. Import both `math.sqrt` and `cmath.sqrt` (with aliases) and show their results for input values `16` and `-16`.

# %%
# Write your solution here

# %% [markdown]
# **Exercise:** 5. Create a mock folder `mypackage/` with two files (`data_utils.py`, `stats_utils.py`).
# - In `data_utils.py`, define a function `load_data()` that returns a simple list `[1,2,3]`.
# - In `stats_utils.py`, define a function `mean(lst)` that returns the average.
# - From another script, import both functions and run them together.

# %%
# Write your solution here

# %% [markdown]
# # Creating Custom Modules Exercises

# %% [markdown]
# **Exercise:** 1. Create `mymath.py` with functions `square(x)` and `cube(x)`. Import and use them in another script.

# %%
# Write your solution here

# %% [markdown]
# **Exercise:** 2. Write `string_utils.py` with functions `reverse_string(s)` and `count_vowels(s)`. Test them by importing into another file.

# %%
# Write your solution here

# %% [markdown]
# **Exercise:** 3. Debugging exercise:
# ```python
# # utils.py
# def add(a, b):
#     return a + b
#
# def multiply(a, b):
#     return a * b
# ```
# But in your main script you try:
# ```python
# from utils import sum
# print(sum(2, 3))
# ```
# Fix the error without changing the function names in `utils.py`.

# %%
# Write your solution here

# %% [markdown]
# **Exercise:** 4. Create a package `textpackage/` with `__init__.py`, `clean.py`, and `analyze.py`.
# - `clean.py`: function `lowercase(s)`
# - `analyze.py`: function `word_count(s)`
# Import `lowercase` inside `analyze.py` using a **relative import** and then test it from a separate script.

# %%
# Write your solution here

# %% [markdown]
# **Exercise:** 5. Write `finance_utils.py` with functions `compound_interest(principal, rate, years)` and `monthly_payment(principal, rate, months)`. Import them in a test script and print results for sample inputs.

# %%
# Write your solution here

# %% [markdown]
# # Standard Library Overview Exercises

# %% [markdown]
# **Exercise:** 1. Use the `datetime` module to print today’s date and the date 30 days from now.

# %%
# Write your solution here

# %% [markdown]
# **Exercise:** 2. Use `os` to list all files in the current directory.

# %%
# Write your solution here

# %% [markdown]
# **Exercise:** 3. Use `sys` to print the Python version you are running.

# %%
# Write your solution here

# %% [markdown]
# **Exercise:** 4. Use `random` to shuffle a list `[1,2,3,4,5]`.

# %%
# Write your solution here

# %% [markdown]
# **Exercise:** 5. Combine `math` and `random`: generate 10 random floats between 0 and 1, then compute their average using `math.fsum`.

# %%
# Write your solution here
