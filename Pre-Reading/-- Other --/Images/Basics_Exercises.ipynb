# %% [markdown]
# # Variables and Data Types Exercises

# %% [markdown]
# **Exercise:** 1. Create variables of type int, float, string, and boolean. Print each with its type using `type()`.

# %%
# Write your solution here

# %% [markdown]
# **Exercise:** 2. Reassign a variable and show how its value changes.

# %%
# Write your solution here

# %% [markdown]
# **Exercise:** 3. Debugging: Try to use a variable before defining it. Observe the error.

# %%
# Write your solution here

# %% [markdown]
# **Exercise:** 4. Store the number of rows in a dataset and the average spend per row. Print both in a formatted string.

# %%
# Write your solution here

# %% [markdown]
# **Exercise:** 5. Create a boolean variable `has_missing` set to True. Use an if-statement to print a message if missing values exist.

# %%
# Write your solution here

# %% [markdown]
# # Operators Exercises

# %% [markdown]
# **Exercise:** 1. Use arithmetic operators to calculate area of a rectangle given width and height variables.

# %%
# Write your solution here

# %% [markdown]
# **Exercise:** 2. Use assignment operators (`+=`, `-=`, `*=`) to modify a counter variable.

# %%
# Write your solution here

# %% [markdown]
# **Exercise:** 3. Debugging: Divide an integer by zero and catch the error.

# %%
# Write your solution here

# %% [markdown]
# **Exercise:** 4. Show the difference between `/` and `//` when dividing two integers.

# %%
# Write your solution here

# %% [markdown]
# **Exercise:** 5. Calculate the remainder of dividing 23 by 5 using `%` and using `divmod()`.

# %%
# Write your solution here

# %% [markdown]
# # Boolean Values and Comparisons Exercises

# %% [markdown]
# **Exercise:** 1. Create two variables (income, credit_score). Write an if-statement that prints 'Approved' if income > 40000 and credit_score > 700.

# %%
# Write your solution here

# %% [markdown]
# **Exercise:** 2. Compare two numbers using all comparison operators (`==`, `!=`, `<`, `<=`, `>`, `>=`). Print results.

# %%
# Write your solution here

# %% [markdown]
# **Exercise:** 3. Demonstrate boolean logic with `and`, `or`, `not` using simple conditions.

# %%
# Write your solution here

# %% [markdown]
# **Exercise:** 4. Show operator precedence: evaluate `True or False and not False`.

# %%
# Write your solution here

# %% [markdown]
# **Exercise:** 5. Debugging: Write a condition with wrong precedence (without parentheses) and then fix it.

# %%
# Write your solution here

# %% [markdown]
# # Useful Built-In Functions Exercises

# %% [markdown]
# **Exercise:** 1. Use `round()` to round a float to 2 decimals.

# %%
# Write your solution here

# %% [markdown]
# **Exercise:** 2. Use `divmod()` to calculate full batches and leftovers for 53 items with batch size 10.

# %%
# Write your solution here

# %% [markdown]
# **Exercise:** 3. Use `isinstance()` to check if a variable is int or float.

# %%
# Write your solution here

# %% [markdown]
# **Exercise:** 4. Use `pow(x, y, z)` to calculate modular exponentiation with custom values.

# %%
# Write your solution here

# %% [markdown]
# **Exercise:** 5. Use `input()` to ask the user for their age and print a message if they are 18 or older.

# %%
# Write your solution here
