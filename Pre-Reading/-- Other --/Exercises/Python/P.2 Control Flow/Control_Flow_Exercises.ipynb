# %% [markdown]
# # If, Elif, Else Exercises

# %% [markdown]
# **Exercise:** 1. Write a program that checks if a number is positive, negative, or zero using if/elif/else.

# %%
# Write your solution here

# %% [markdown]
# **Exercise:** 2. Check if a customer is eligible for a loan: condition is age >= 18 and credit_score > 700.

# %%
# Write your solution here

# %% [markdown]
# **Exercise:** 3. Debugging: Write an if-statement without colon `:` and observe the error.

# %%
# Write your solution here

# %% [markdown]
# **Exercise:** 4. Nested conditions: check if a variable is not None, is integer, and > 10. Print appropriate messages.

# %%
# Write your solution here

# %% [markdown]
# **Exercise:** 5. Combine conditions with `and` and `or` to check if a student passes (score > 50) or has extra credit.

# %%
# Write your solution here

# %% [markdown]
# # For Loops Exercises

# %% [markdown]
# **Exercise:** 1. Loop through a list of prices and calculate the total spend.

# %%
# Write your solution here

# %% [markdown]
# **Exercise:** 2. Use a for loop to print numbers from 1 to 5.

# %%
# Write your solution here

# %% [markdown]
# **Exercise:** 3. Loop through a string and print each character on a new line.

# %%
# Write your solution here

# %% [markdown]
# **Exercise:** 4. Loop through a dictionary of students and print their names and grades.

# %%
# Write your solution here

# %% [markdown]
# **Exercise:** 5. Debugging: Loop with wrong indentation. Observe the error.

# %%
# Write your solution here

# %% [markdown]
# # While Loops Exercises

# %% [markdown]
# **Exercise:** 1. Write a while loop that counts from 1 to 5.

# %%
# Write your solution here

# %% [markdown]
# **Exercise:** 2. Write a while loop that doubles a number until it exceeds 100.

# %%
# Write your solution here

# %% [markdown]
# **Exercise:** 3. Debugging: Create a while loop with missing increment. Observe infinite loop (be careful).

# %%
# Write your solution here

# %% [markdown]
# **Exercise:** 4. Write a while loop that keeps asking for input until the user types 'exit'.

# %%
# Write your solution here

# %% [markdown]
# **Exercise:** 5. Simulate increasing correlation until it exceeds 0.8 as in the notes.

# %%
# Write your solution here

# %% [markdown]
# # Loop Control Statements Exercises

# %% [markdown]
# **Exercise:** 1. Write a loop that prints numbers 1–10 but stops at 5 using `break`.

# %%
# Write your solution here

# %% [markdown]
# **Exercise:** 2. Write a loop that prints numbers 1–10 but skips 5 using `continue`.

# %%
# Write your solution here

# %% [markdown]
# **Exercise:** 3. Write a loop that prints only even numbers using `continue`.

# %%
# Write your solution here

# %% [markdown]
# **Exercise:** 4. Write a loop with `else` that prints 'Loop finished successfully' only if no break occurred.

# %%
# Write your solution here

# %% [markdown]
# **Exercise:** 5. Write a placeholder loop that does nothing inside (`pass`).

# %%
# Write your solution here
