# %% [markdown]
# # Basic Functions Exercises

# %% [markdown]
# **Exercise:** 1. Define a function with no parameters that prints 'Hello'. Call it.

# %%
# Write your solution here

# %% [markdown]
# **Exercise:** 2. Define a function with parameters that calculates final price after discount.

# %%
# Write your solution here

# %% [markdown]
# **Exercise:** 3. Write a function that uses both `print` and `return`. Show difference in behaviour.

# %%
# Write your solution here

# %% [markdown]
# **Exercise:** 4. Debugging: Define a function but forget parentheses in call. Observe error.

# %%
# Write your solution here

# %% [markdown]
# **Exercise:** 5. Modify function to accept float inputs and round result.

# %%
# Write your solution here

# %% [markdown]
# # Scope and Lifetime Exercises

# %% [markdown]
# **Exercise:** 1. Write a function with a local variable. Try to access it outside and handle the error.

# %%
# Write your solution here

# %% [markdown]
# **Exercise:** 2. Create a global variable and modify it inside a function using `global`.

# %%
# Write your solution here

# %% [markdown]
# **Exercise:** 3. Create a nested function and modify an outer variable using `nonlocal`.

# %%
# Write your solution here

# %% [markdown]
# **Exercise:** 4. Write code that shadows a built-in name (like `list=5`). See what happens.

# %%
# Write your solution here

# %% [markdown]
# **Exercise:** 5. Debugging: Fix variable scope issue where modifying inside function doesn’t persist.

# %%
# Write your solution here

# %% [markdown]
# # Docstrings Exercises

# %% [markdown]
# **Exercise:** 1. Write a function with a proper docstring. Use `help()` to display it.

# %%
# Write your solution here

# %% [markdown]
# **Exercise:** 2. Write docstrings for parameters and return values.

# %%
# Write your solution here

# %% [markdown]
# **Exercise:** 3. Modify a function to include a multi-line docstring.

# %%
# Write your solution here

# %% [markdown]
# **Exercise:** 4. Use a docstring to document a simple Pandas helper function.

# %%
# Write your solution here

# %% [markdown]
# **Exercise:** 5. Debugging: Write function without docstring. Use `help()` and observe result.

# %%
# Write your solution here

# %% [markdown]
# # Lambda Functions Exercises

# %% [markdown]
# **Exercise:** 1. Write a lambda function that doubles a number.

# %%
# Write your solution here

# %% [markdown]
# **Exercise:** 2. Use lambda in `sorted()` to sort list of tuples by second element.

# %%
# Write your solution here

# %% [markdown]
# **Exercise:** 3. Use lambda with `map()` to square a list of numbers.

# %%
# Write your solution here

# %% [markdown]
# **Exercise:** 4. Use lambda with `filter()` to get even numbers from list.

# %%
# Write your solution here

# %% [markdown]
# **Exercise:** 5. Debugging: Compare normal function vs lambda for same task.

# %%
# Write your solution here

# %% [markdown]
# # Nested Functions and Closures Exercises

# %% [markdown]
# **Exercise:** 1. Write a function that returns another function. Call the returned function.

# %%
# Write your solution here

# %% [markdown]
# **Exercise:** 2. Demonstrate closure: outer function defines variable, inner function uses it.

# %%
# Write your solution here

# %% [markdown]
# **Exercise:** 3. Debugging: Forget `nonlocal`. Show how it affects variable update.

# %%
# Write your solution here

# %% [markdown]
# **Exercise:** 4. Write a nested function that calculates mean of a Pandas column.

# %%
# Write your solution here

# %% [markdown]
# **Exercise:** 5. Create two closures that remember different values.

# %%
# Write your solution here

# %% [markdown]
# # Decorators Exercises

# %% [markdown]
# **Exercise:** 1. Write a decorator that prints 'Before' and 'After' around a function call.

# %%
# Write your solution here

# %% [markdown]
# **Exercise:** 2. Write a decorator that times execution of a function.

# %%
# Write your solution here

# %% [markdown]
# **Exercise:** 3. Apply decorator syntax `@decorator` to a function and test.

# %%
# Write your solution here

# %% [markdown]
# **Exercise:** 4. Debugging: Write decorator but forget to return wrapper. Fix it.

# %%
# Write your solution here

# %% [markdown]
# **Exercise:** 5. Write a decorator for a Pandas data-loading function that prints shape of DataFrame.

# %%
# Write your solution here

# %% [markdown]
# # Recursion Exercises

# %% [markdown]
# **Exercise:** 1. Write a recursive function to calculate factorial of n.

# %%
# Write your solution here

# %% [markdown]
# **Exercise:** 2. Write a recursive function to calculate nth Fibonacci number.

# %%
# Write your solution here

# %% [markdown]
# **Exercise:** 3. Write a recursive function to count missing values in a list (like in notes).

# %%
# Write your solution here

# %% [markdown]
# **Exercise:** 4. Debugging: Forget base case in recursion. Observe RecursionError.

# %%
# Write your solution here

# %% [markdown]
# **Exercise:** 5. Modify recursion to handle empty list safely.

# %%
# Write your solution here
