# %% [markdown]
# # Reading and Writing Text Files Exercises

# %% [markdown]
# **Exercise:** 1. Create a new text file `notes.txt` and write three lines of text into it using write mode (`w`). Then open it again in read mode and print its contents.

# %%
# Write your solution here

# %% [markdown]
# **Exercise:** 2. Append two more lines to `notes.txt` without overwriting the original contents. Then read and print the whole file.

# %%
# Write your solution here

# %% [markdown]
# **Exercise:** 3. Try to open a non-existent file in read mode and handle the error gracefully using `try/except`.

# %%
# Write your solution here

# %% [markdown]
# **Exercise:** 4. Use the `with` keyword to safely open a file, read its contents, and show that it automatically closes by printing `f.closed` after the block.

# %%
# Write your solution here

# %% [markdown]
# **Exercise:** 5. Write a program that reads all lines of `notes.txt` into a list, strips newline characters, and prints the list.

# %%
# Write your solution here

# %% [markdown]
# # Importance of `with` Keyword Exercises

# %% [markdown]
# **Exercise:** 1. Demonstrate what happens if you forget to close a file after opening it without `with`. Use `f.closed` to confirm.

# %%
# Write your solution here

# %% [markdown]
# **Exercise:** 2. Open `notes.txt` using `with open(..., 'r') as f` and prove that `f.closed` is True after the block ends.

# %%
# Write your solution here

# %% [markdown]
# **Exercise:** 3. Explain in comments what `__enter__()` and `__exit__()` do when using `with`.

# %%
# Write your solution here

# %% [markdown]
# **Exercise:** 4. Modify a program so that file closing happens automatically without explicitly calling `f.close()`.

# %%
# Write your solution here

# %% [markdown]
# **Exercise:** 5. Create a deliberate error inside a `with` block (e.g., divide by zero) and check if the file still closes.

# %%
# Write your solution here

# %% [markdown]
# # CSV Basics Exercises

# %% [markdown]
# **Exercise:** 1. Create a CSV file `students.csv` with columns `Name` and `Score`. Add three rows of data manually in your code.

# %%
# Write your solution here

# %% [markdown]
# **Exercise:** 2. Use `csv.reader` to read `students.csv` and print each row.

# %%
# Write your solution here

# %% [markdown]
# **Exercise:** 3. Use `csv.writer` to add another student record to the CSV file without overwriting existing data.

# %%
# Write your solution here

# %% [markdown]
# **Exercise:** 4. Read `students.csv` and calculate the average score (remember that CSV values are strings—convert them).

# %%
# Write your solution here

# %% [markdown]
# **Exercise:** 5. Compare results: load the same file with `pandas.read_csv` and print the DataFrame head.

# %%
# Write your solution here

# %% [markdown]
# # Pandas Chunking Exercises

# %% [markdown]
# **Exercise:** 1. Create a large CSV file by writing 1000 rows of sample numeric data programmatically. Save it as `big.csv`.

# %%
# Write your solution here

# %% [markdown]
# **Exercise:** 2. Use `pd.read_csv` without `chunksize` and print the shape. What happens if the file is too large for memory?

# %%
# Write your solution here

# %% [markdown]
# **Exercise:** 3. Use `chunksize=200` to read `big.csv` in smaller pieces. Print the shape of each chunk.

# %%
# Write your solution here

# %% [markdown]
# **Exercise:** 4. Using chunking, calculate the mean of one numeric column across the entire file without loading it all into memory.

# %%
# Write your solution here

# %% [markdown]
# **Exercise:** 5. Compare performance: read the file normally vs in chunks and measure the time taken (use `%time` magic in Jupyter).

# %%
# Write your solution here
