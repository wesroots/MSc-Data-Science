# %% [markdown]
# # Positional Arguments Exercises

# %% [markdown]
# **Exercise:** 1. Write a function that takes two positional arguments (width, height) and returns the area of a rectangle. Call it with values 5 and 10.

# %%
# Write your solution here

# %% [markdown]
# **Exercise:** 2. Call a NumPy function (e.g., `np.mean`) with a list of numbers as a positional argument. Print the result.

# %%
# Write your solution here

# %% [markdown]
# **Exercise:** 3. Debugging: Define a function with two required parameters, but call it with only one. Catch the resulting error.

# %%
# Write your solution here

# %% [markdown]
# **Exercise:** 4. Write a function that accepts three numbers and returns their sum. Call it with positional arguments in different orders.

# %%
# Write your solution here

# %% [markdown]
# **Exercise:** 5. Compare function calls using positional vs incorrect ordering (e.g., swapped values). Explain why results differ.

# %%
# Write your solution here

# %% [markdown]
# # Keyword Arguments Exercises

# %% [markdown]
# **Exercise:** 1. Define a function that calculates BMI given `weight` and `height`. Call it using keyword arguments in different orders.

# %%
# Write your solution here

# %% [markdown]
# **Exercise:** 2. Call `pd.read_csv` with keyword arguments (`sep`, `usecols`, `parse_dates`). Test by printing `df.head()`.

# %%
# Write your solution here

# %% [markdown]
# **Exercise:** 3. Debugging: Define a function with named parameters. Call it with a keyword that doesn’t exist. Handle the resulting error.

# %%
# Write your solution here

# %% [markdown]
# **Exercise:** 4. Write a function that takes parameters `name`, `age`, `city` and call it with keyword arguments in flexible order.

# %%
# Write your solution here

# %% [markdown]
# **Exercise:** 5. Show how keyword arguments can skip defaults (e.g., call `print('Hello', end='***')`).

# %%
# Write your solution here

# %% [markdown]
# # Default Arguments Exercises

# %% [markdown]
# **Exercise:** 1. Define a function `greet(name, greeting='Hello')` and call it both with and without the second argument.

# %%
# Write your solution here

# %% [markdown]
# **Exercise:** 2. Define a function with multiple defaults. Override one while leaving others unchanged.

# %%
# Write your solution here

# %% [markdown]
# **Exercise:** 3. Debugging: Create a function with mutable default (like `list=[]`). Show what happens when it’s called multiple times.

# %%
# Write your solution here

# %% [markdown]
# **Exercise:** 4. Write a logging function with a default log level 'INFO'. Call it with and without overriding the level.

# %%
# Write your solution here

# %% [markdown]
# **Exercise:** 5. Demonstrate a Pandas function (like `pd.read_csv`) that uses defaults, then override one of them.

# %%
# Write your solution here

# %% [markdown]
# # Variable-Length Arguments (*args and **kwargs) Exercises

# %% [markdown]
# **Exercise:** 1. Write a function that accepts any number of positional arguments (`*args`) and returns their sum.

# %%
# Write your solution here

# %% [markdown]
# **Exercise:** 2. Write a function that accepts any number of keyword arguments (`**kwargs`) and prints them.

# %%
# Write your solution here

# %% [markdown]
# **Exercise:** 3. Use `*args` in a function to multiply any number of numbers together.

# %%
# Write your solution here

# %% [markdown]
# **Exercise:** 4. Use `**kwargs` in a wrapper around `pd.read_csv` to pass extra options dynamically.

# %%
# Write your solution here

# %% [markdown]
# **Exercise:** 5. Write a function that accepts both `*args` and `**kwargs`. Call it with mixed arguments.

# %%
# Write your solution here

# %% [markdown]
# # Argument Unpacking Exercises

# %% [markdown]
# **Exercise:** 1. Define a function that takes three numbers. Store them in a list and use `*` to unpack into the function.

# %%
# Write your solution here

# %% [markdown]
# **Exercise:** 2. Write a function with keyword parameters. Store arguments in a dict and unpack with `**`.

# %%
# Write your solution here

# %% [markdown]
# **Exercise:** 3. Create a function that prints stats of three columns. Pass them using `*` unpacking from a list of Series.

# %%
# Write your solution here

# %% [markdown]
# **Exercise:** 4. Create a wrapper function that forwards arguments to another function using unpacking.

# %%
# Write your solution here

# %% [markdown]
# **Exercise:** 5. Debugging: Call a function expecting 3 arguments using a list of 2. Handle the error.

# %%
# Write your solution here

# %% [markdown]
# # Returning Multiple Values Exercises

# %% [markdown]
# **Exercise:** 1. Write a function that returns the sum and product of two numbers. Unpack results into variables.

# %%
# Write your solution here

# %% [markdown]
# **Exercise:** 2. Write a function that returns mean and median of a list. Unpack into `mean_val, median_val`.

# %%
# Write your solution here

# %% [markdown]
# **Exercise:** 3. Modify a function to return a dictionary instead of tuple. Access values by key.

# %%
# Write your solution here

# %% [markdown]
# **Exercise:** 4. Write a Pandas function that returns mean of two columns. Call it and unpack results.

# %%
# Write your solution here

# %% [markdown]
# **Exercise:** 5. Debugging: Call a function returning two values but try unpacking into three variables. Handle the error.

# %%
# Write your solution here
